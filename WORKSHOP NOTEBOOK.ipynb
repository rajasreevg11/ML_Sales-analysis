# %% [markdown]
# ## IMPORT LIBRARIES
#
# First, let’s import all of the modules, functions and objects we are going to use in this tutorial.

# %% [markdown]
# ## IMPORT LIBRARIES
#
# import pandas as pd
#
# import seaborn as sns
#
# import numpy as np
#
# import matplotlib.pyplot as plt
#
# import warnings
#
# from sklearn.preprocessing import StandardScaler
#
# from sklearn.cluster import KMeans
#
# from sklearn.model_selection import train_test_split
#
#
# from sklearn.linear_model import LogisticRegression
#
#
# from sklearn.metrics import accuracy_score, classification_report, silhouette_score

# %%
import pandas as pd

import seaborn as sns

import numpy as np

import matplotlib.pyplot as plt

import warnings

from sklearn.preprocessing import StandardScaler

from sklearn.cluster import KMeans

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score, classification_report, silhouette_score

# %%
#Install seaborn if not installed
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\admin\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\admin\anaconda3\lib\site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: numpy>=1.15 in c:\users\admin\anaconda3\lib\site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: scipy>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\admin\anaconda3\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)

# %% [markdown]
# ## About Dataset
# Shop Customer Data is a detailed analysis of a imaginative shop's ideal customers. It helps a business to better understand its customers. The owner of a shop gets information about Customers through membership cards.
#
# Dataset consists of 2000 records and 8 columns:
#
# Customer ID
#
# Gender
#
# Age
#
# Annual Income
#
# Spending Score - Score assigned by the shop, based on customer behavior and spending nature
#
# Profession
#
# Work Experience - in years
#
# Family Size

# %% [markdown]
# ## LOAD DATASET
# We are using pandas to load the data. We will also use pandas next to explore the data both with descriptive statistics and data visualization.
#
#
# dataset = pd.read_csv("https://raw.githubusercontent.com/leenaali1114/Customers-Dataset/main/Customers.csv")

# %%
#Type the above code snippet in this code cell and click Run.
#dataset=................
dataset = pd.read_csv("Customers.csv")

# %% [markdown]
# ![Screenshot%202023-05-26%20102047.png](attachment:Screenshot%202023-05-26%20102047.png)

# %% [markdown]
# ## EDA
#
# Exploratory Data Analysis is a data analytics process to understand the data in depth and learn the different data characteristics, often with visual means. This allows you to get a better feel of your data and find useful patterns in it.
#
# #### Summarize the Dataset
# Now it is time to take a look at the data.
#
# In this step we are going to take a look at the data a few different ways:
#
#     1.Dimensions of the dataset.
#     2.Peek at the data itself.
#     3.Statistical summary of all attributes.
#     4.Breakdown of the data by the class variable.
# Don’t worry, each look at the data is one command. These are useful commands that you can use again and again on future projects.
#
# #### Dimensions of Dataset
# We can get a quick idea of how many instances (rows) and how many attributes (columns) the data contains with the shape property.
#
#
# #### Shape
# The DataFrame.shape attribute in Pandas enables us to obtain the shape of a DataFrame. For example, if a DataFrame has a shape of (80, 10) , this implies that the DataFrame is made up of 80 rows and 10 columns of data.
#
# dataset.shape

# %%
#Type the above code snippet in this code cell and click Run.
#dataset................

dataset.shape
# Out:
# (2000, 10)

# %% [markdown]
# dataset.head()

# %%
#Type the above code snippet in this code cell and click Run.
#dataset................
dataset.head(25)
# Out:
#     CustomerID  Gender  Age  Annual_Income  Spending_Score     Profession  \
# 0            1    Male   19          15000              39     Healthcare
# 1            2    Male   21          35000              81       Engineer
# 2            3  Female   20          86000               6       Engineer
# 3            4  Female   23          59000              77         Lawyer
# 4            5  Female   31          38000              40  Entertainment
# 5            6  Female   22          58000              76         Artist
# 6            7  Female   35          31000               6     Healthcare
# 7            8  Female   23          84000              94     Healthcare
# 8            9    Male   64          97000               3       Engineer
# 9           10  Female   30          98000              72         Artist
# 10          11    Male   67           7000              14       Engineer
# 11          12  Female   35          93000              99     Healthcare
# 12          13  Female   58          80000              15      Executive
# 13          14  Female   24          91000              77         Lawyer
# 14          15    Male   37          19000              13         Doctor
# 15          16    Male   22          51000              79     Healthcare
# 16          17  Female   35          29000              35      Homemaker
# 17          18    Male   20          89000              66     Healthcare
# 18          19    Male   52          20000              29  Entertainment
# 19          20  Female   35          62000              98         Artist
# 20          21    Male   35          96000              35      Homemaker
# 21          22    Male   25           4000              73     Healthcare
# 22          23  Female   46          42000               5         Artist
# 23          24    Male   31          71000              73         Artist
# 24          25  Female   54          67000              14      Executive
#
#     Work_Experience  Family Size Spending_Category  Invoice_Number
# 0                 1            4           Average          458984
# 1                 3            3              High          458994
# 2                 1            1               Low          458994
# 3                 0            2              High          458997
# 4                 2            6           Average          458999
# 5                 0            2              High          459007
# 6                 1            3               Low          459008
# 7                 1            3              High          459008
# 8                 0            3               Low          459009
# 9                 1            4              High          459010
# 10                1            3               Low          459013
# 11                4            4              High          459013
# 12                0            5               Low          459020
# 13                1            1              High          459024
# 14                0            1               Low          459024
# 15                1            2              High          459027
# 16                9            5           Average          459036
# 17                1            6              High          459036
# 18                1            4           Average          459039
# 19                0            1              High          459039
# 20               12            1           Average          459042
# 21                3            4              High          459044
# 22               13            2               Low          459045
# 23                5            2              High          459051
# 24                1            3               Low          459069

# %% [markdown]
# dataset.tail()

# %%
#Type the above code snippet in this code cell and click Run.
#dataset................

dataset.tail()
# Out:
#       CustomerID  Gender  Age  Annual_Income  Spending_Score     Profession  \
# 1995        1996  Female   71         184387              40         Artist
# 1996        1997  Female   91          73158              32         Doctor
# 1997        1998    Male   87          90961              14     Healthcare
# 1998        1999    Male   77         182109               4      Executive
# 1999        2000    Male   90         110610              52  Entertainment
#
#       Work_Experience  Family Size Spending_Category  Invoice_Number
# 1995                8            7           Average          461768
# 1996                7            7           Average          461773
# 1997                9            2               Low          461774
# 1998                7            2               Low          461775
# 1999                5            2              High          461775

# %% [markdown]
# ### Statistical Summary
# Now we can take a look at a summary of each attribute.
#
# This includes the count, mean, the min and max values as well as some percentiles.
#
#
#
#
# dataset.info()

# %%
#Type the above code snippet in this code cell and click Run.
#dataset................

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         2000 non-null   int64
#  1   Gender             2000 non-null   object
#  2   Age                2000 non-null   int64
#  3   Annual_Income      2000 non-null   int64
#  4   Spending_Score     2000 non-null   int64
#  5   Profession         1965 non-null   object
#  6   Work_Experience    2000 non-null   int64
#  7   Family Size        2000 non-null   int64
#  8   Spending_Category  2000 non-null   object
#  9   Invoice_Number     2000 non-null   int64
# dtypes: int64(7), object(3)
# memory usage: 156.4+ KB

# %% [markdown]
# dataset.describe()

# %%
#Type the above code snippet in this code cell and click Run.
#dataset................

dataset.describe()
# Out:
#         CustomerID          Age  Annual_Income  Spending_Score  \
# count  2000.000000  2000.000000    2000.000000     2000.000000
# mean   1000.500000    48.960000  110731.821500       50.962500
# std     577.494589    28.429747   45739.536688       27.934661
# min       1.000000     0.000000       0.000000        0.000000
# 25%     500.750000    25.000000   74572.000000       28.000000
# 50%    1000.500000    48.000000  110045.000000       50.000000
# 75%    1500.250000    73.000000  149092.750000       75.000000
# max    2000.000000    99.000000  189974.000000      100.000000
#
#        Work_Experience  Family Size  Invoice_Number
# count      2000.000000  2000.000000     2000.000000
# mean          4.102500     3.768500   461389.611000
# std           3.922204     1.970749     1529.636635
# min           0.000000     1.000000   458984.000000
# 25%           1.000000     2.000000   459890.500000
# 50%           3.000000     4.000000   461425.000000
# 75%           7.000000     5.000000   462654.750000
# max          17.000000     9.000000   464252.000000

# %% [markdown]
# ## Univariate Analysis
# Univariate analysis is the simplest form of analysis where we explore a single variable. Univariate analysis is performed to describe the data in a better way. We perform Univariate analysis of Numerical and categorical variables differently because plotting uses different plots.
#
# #### Categorical Data
# ##### CountPlot
#
# Countplot is basically a count of frequency plot in form of a bar graph. It plots the count of each category in a separate bar. When we use the pandas’ value counts function on any column, It is the same visual form of the value counts function.
#
#
# ##### Seaborn
# Python Seaborn library is a widely popular data visualization library that is commonly used for data science and machine learning tasks. You build it on top of the matplotlib data visualization library and can perform exploratory analysis.

# %% [markdown]
# !pip install seaborn
#
# import seaborn as sns
#
# sns.countplot(x = 'Profession', data=dataset, order = dataset['Profession'].value_counts().index)

# %%
#Type the above code snippet in this code cell and click Run.
#import seaborn................

sns.countplot(x = 'Profession', data=dataset, order = dataset['Profession'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='Profession', ylabel='count'>

# %% [markdown]
# ##### Pie Chart
#
# The pie chart is also the same as the countplot, only gives you additional information about the percentage presence of each category in data, means which category is getting how much weightage in data. If we check the Gender column we get an overview about the male and female shoppers.

# %% [markdown]
# dataset['Gender'].value_counts().plot(kind="pie", autopct="%.2f")
#
# plt.show()

# %%
#Type the above code snippet in this code cell and click Run.
#import dataset['Gender']................

dataset['Gender'].value_counts().plot(kind="pie", autopct="%.2f")

plt.show()

# %% [markdown]
# #### Numerical Data
#
# ##### Histogram
#
# A histogram is a value distribution plot of numerical columns. It basically creates bins in various ranges in values and plots it where we can visualize how values are distributed. We can have a look where more values lie like in positive, negative, or at the center(mean).

# %% [markdown]
# plt.hist(dataset['Age'], bins=10)
#
# plt.show()

# %%
#Type the above code snippet in this code cell and click Run.
# plt.hist................

plt.hist(dataset['Age'], bins=10)

plt.show()

# %% [markdown]
# ##### Histplot
#
# Histplot is also known as the second Histogram because it is a slight improvement version of the Histogram. Distplot gives us a KDE(Kernel Density Estimation) over histogram which explains PDF(Probability Density Function) which means what is the probability of each value occurring in this column. If you have study statistics before then definitely you should know about PDF function.
#
# sns.histplot(data=dataset, x='Spending_Score',color='pink',kde=True)

# %%
#Type the above code snippet in this code cell and click Run.
# sns.histplot................
sns.histplot(data=dataset, x='Spending_Score',color='pink',kde=True)
# Out:
# <AxesSubplot:xlabel='Spending_Score', ylabel='Count'>

# %%
#box Plot:5 number summary,finding outlier

dataset.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False)

plt.show()

# %% [markdown]
# ## Bivariate/ Multivariate Analysis
# We dicussed about various plots to explore single categorical and numerical data. Bivariate Analysis is used when we have to explore the relationship between 2 different variables and we have to do this because, in the end, our main task is to explore the relationship between variables to build a powerful model. And when we analyze more than 2 variables together then it is known as Multivariate Analysis. we will work on different plots for Bivariate as well on Multivariate Analysis.
#
# #### Numerical and Numerical
# First, let’s explore the plots when both the variable is numerical.
#
# ###### Scatter Plot
# To plot the relationship between two numerical variables scatter plot is a simple plot to do. Let us see the relationship between the total bill and tip provided using a scatter plot.

# %%
sns.scatterplot(data=dataset,x=dataset["Spending_Score"], y=dataset["Annual_Income"], hue=dataset["Gender"])
plt.show()

# %%
sns.set_style("whitegrid")
sns.pairplot(dataset, hue="Work_Experience", height=2)
plt.show()

# %%
#compare featutes that are not related

sns.jointplot(data=dataset, x='Age', y='Annual_Income',color='purple')

# %%
sns.barplot(data=dataset, x='Work_Experience',y='Annual_Income',ci=None)
# Out:
# <AxesSubplot:xlabel='Work_Experience', ylabel='Annual_Income'>

# %%
sns.countplot(x = 'Spending_Category', data=dataset, order = dataset['Spending_Category'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='Spending_Category', ylabel='count'>

# %% [markdown]
# # DATA ENGINEERING

# %%
dataset.head()
# Out:
#    CustomerID  Gender  Age  Annual_Income  Spending_Score     Profession  \
# 0           1    Male   19          15000              39     Healthcare
# 1           2    Male   21          35000              81       Engineer
# 2           3  Female   20          86000               6       Engineer
# 3           4  Female   23          59000              77         Lawyer
# 4           5  Female   31          38000              40  Entertainment
#
#    Work_Experience  Family Size Spending_Category  Invoice_Number
# 0                1            4           Average          458984
# 1                3            3              High          458994
# 2                1            1               Low          458994
# 3                0            2              High          458997
# 4                2            6           Average          458999

# %%
dataset=dataset.drop(['CustomerID'], axis=1)

# %%
dataset = dataset.drop(['Spending_Score', 'Invoice_Number'], axis=1)

# %%
dataset
# Out:
#       Gender  Age  Annual_Income     Profession  Work_Experience  Family Size  \
# 0       Male   19          15000     Healthcare                1            4
# 1       Male   21          35000       Engineer                3            3
# 2     Female   20          86000       Engineer                1            1
# 3     Female   23          59000         Lawyer                0            2
# 4     Female   31          38000  Entertainment                2            6
# ...      ...  ...            ...            ...              ...          ...
# 1995  Female   71         184387         Artist                8            7
# 1996  Female   91          73158         Doctor                7            7
# 1997    Male   87          90961     Healthcare                9            2
# 1998    Male   77         182109      Executive                7            2
# 1999    Male   90         110610  Entertainment                5            2
#
#      Spending_Category
# 0              Average
# 1                 High
# 2                  Low
# 3                 High
# 4              Average
# ...                ...
# 1995           Average
# 1996           Average
# 1997               Low
# 1998               Low
# 1999              High
#
# [2000 rows x 7 columns]

# %%
dataset.groupby('Spending_Category').size()
#finding the category values
# Out:
# Spending_Category
# Average     639
# High       1017
# Low         344
# dtype: int64

# %%
#Most important machine learning library-resample :accurancy increase cheyyan. 


from sklearn.utils import resample
#create two different dataframe of majority and minority class 
ds_low = dataset[(dataset['Spending_Category']=="Low")] 
ds_average = dataset[(dataset['Spending_Category']=="Average")] 
ds_high = dataset[(dataset['Spending_Category']=="High")]
# upsample minority class
ds_average_upsampled = resample(ds_average, 
                                 replace=True,    # sample with replacement
                                 n_samples= 1017, # to match majority class
                                 random_state=42)  # reproducible results
ds_low_upsampled = resample(ds_low, 
                                 replace=True,    # sample with replacement
                                 n_samples= 1017, # to match majority class
                                 random_state=42)  # reproducible results

# Combine majority class with upsampled minority class
ds = pd.concat([ds_average_upsampled,ds_low_upsampled, ds_high])

# %%
#balanced data set

ds.groupby('Spending_Category').size()
# Out:
# Spending_Category
# Average    1017
# High       1017
# Low        1017
# dtype: int64

# %%
#find the number of duplicated data

ds.duplicated().sum()
# Out:
# 1220

# %%
sns.countplot(x = 'Spending_Category', data=ds, order = dataset['Spending_Category'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='Spending_Category', ylabel='count'>

# %%
ds.isnull().sum()
# Out:
# Gender                0
# Age                   0
# Annual_Income         0
# Profession           62
# Work_Experience       0
# Family Size           0
# Spending_Category     0
# dtype: int64

# %%
# replacing null value


ds["Profession"].fillna("Unknown", inplace=True)

# %%
ds.isnull().sum()
# Out:
# Gender               0
# Age                  0
# Annual_Income        0
# Profession           0
# Work_Experience      0
# Family Size          0
# Spending_Category    0
# dtype: int64

# %%
ds
# Out:
#       Gender  Age  Annual_Income     Profession  Work_Experience  Family Size  \
# 348   Female   24         151085      Marketing                2            5
# 1386  Female   82          62951         Lawyer                8            2
# 853   Female   11         143047      Executive                1            3
# 369   Female   36          87353  Entertainment                1            5
# 229     Male   15          94000     Healthcare                7            2
# ...      ...  ...            ...            ...              ...          ...
# 1990  Female   30         166983         Artist                7            3
# 1991  Female   97         129444  Entertainment                5            6
# 1993  Female   64         175254         Artist                9            5
# 1994  Female   19          54121       Engineer                6            3
# 1999    Male   90         110610  Entertainment                5            2
#
#      Spending_Category
# 348            Average
# 1386           Average
# 853            Average
# 369            Average
# 229            Average
# ...                ...
# 1990              High
# 1991              High
# 1993              High
# 1994              High
# 1999              High
#
# [3051 rows x 7 columns]

# %%
sns.countplot(x = 'Profession', data=ds, order = ds['Profession'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='Profession', ylabel='count'>

# %%
ds['Profession'].unique()
# Out:
# array(['Marketing', 'Lawyer', 'Executive', 'Entertainment', 'Healthcare',
#        'Engineer', 'Artist', 'Doctor', 'Unknown', 'Homemaker'],
#       dtype=object)

# %%
#creating dictonary and giving numerical values

prof = {"Marketing":0,'Lawyer':1, 'Executive':2, 'Entertainment':3, 'Healthcare':4,
       'Engineer':5, 'Artist':6, 'Doctor':7, 'Unknown':8, 'Homemaker':9}
ds['Profession'] = ds['Profession'].map(prof)

# %%
ds.head()
# Out:
#       Gender  Age  Annual_Income  Profession  Work_Experience  Family Size  \
# 348   Female   24         151085           0                2            5
# 1386  Female   82          62951           1                8            2
# 853   Female   11         143047           2                1            3
# 369   Female   36          87353           3                1            5
# 229     Male   15          94000           4                7            2
#
#      Spending_Category
# 348            Average
# 1386           Average
# 853            Average
# 369            Average
# 229            Average

# %%
ds['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
gender = {"Male":0,'Female':1}
ds['Gender'] = dataset['Gender'].map(gender)

# %%
ds.head()
# Out:
#       Gender  Age  Annual_Income  Profession  Work_Experience  Family Size  \
# 348        1   24         151085           0                2            5
# 1386       1   82          62951           1                8            2
# 853        1   11         143047           2                1            3
# 369        1   36          87353           3                1            5
# 229        0   15          94000           4                7            2
#
#      Spending_Category
# 348            Average
# 1386           Average
# 853            Average
# 369            Average
# 229            Average

# %%
scaled_ds = ds[['Gender', 'Age', 'Annual_Income', 'Profession', 'Work_Experience','Family Size']]

# %%
scaler=StandardScaler()
scaled_features = scaler.fit_transform(scaled_ds)

# %%
scaled_ds

# %% [markdown]
# # DATA MODELLING & EVALUATION

# %%
#seperating features and target
#Hold-out

x = ds.iloc[:,0:6].values
y = ds.iloc[:,6].values

# %%
x
# Out:
# array([[     1,     24, 151085,      0,      2,      5],
#        [     1,     82,  62951,      1,      8,      2],
#        [     1,     11, 143047,      2,      1,      3],
#        ...,
#        [     1,     64, 175254,      6,      9,      5],
#        [     1,     19,  54121,      5,      6,      3],
#        [     0,     90, 110610,      3,      5,      2]], dtype=int64)

# %%
y
# Out:
# array(['Average', 'Average', 'Average', ..., 'High', 'High', 'High'],
#       dtype=object)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 1)

# %%
print("x_train: ",x_train.shape)
print("y_train: ",y_train.shape)
print("x_test: ",x_test.shape)
print("y_test: ",y_test.shape)
# Out:
# x_train:  (2135, 6)
# y_train:  (2135,)
# x_test:  (916, 6)
# y_test:  (916,)

# %% [markdown]
# #### Logistic Regression

# %%
model_lr = LogisticRegression(max_iter = 600)

# %%
model_lr.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=600)

# %%
y_pred_lr = model_lr.predict(x_test)

# %%
print("Accuracy : ", accuracy_score(y_test, y_pred_lr))
# Out:
# Accuracy :  0.3318777292576419

# %% [markdown]
# #### K Nearest Neighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn = KNeighborsClassifier()

# %%
model_knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn = model_knn.predict(x_test)
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
print("Accuracy : ", accuracy_score(y_test, y_pred_knn))
# Out:
# Accuracy :  0.5120087336244541

# %% [markdown]
# #### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model_dt = DecisionTreeClassifier()

# %%
model_dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dt = model_dt.predict(x_test)

# %%
print("Accuracy : ", accuracy_score(y_test, y_pred_dt))
# Out:
# Accuracy :  0.7117903930131004

# %% [markdown]
# #### Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model_nb = GaussianNB()

# %%
model_nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred_nb = model_nb.predict(x_test)

# %%
print("Accuracy : ", accuracy_score(y_test, y_pred_nb))
# Out:
# Accuracy :  0.35043668122270744

# %% [markdown]
# #### Support Vector Machine

# %%
from sklearn.svm import SVC

# %%
model_svc = SVC(gamma='auto')

# %%
model_svc.fit(x_train,y_train)
# Out:
# SVC(gamma='auto')

# %%
y_pred_svc = model_nb.predict(x_test)

# %%
print("Accuracy : ", accuracy_score(y_test, y_pred_svc))
# Out:
# Accuracy :  0.35043668122270744

# %% [markdown]
# #### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf = RandomForestClassifier(n_estimators = 30, criterion = 'entropy', random_state = 0)

# %%
model_rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=30, random_state=0)

# %%
y_pred_rf = model_nb.predict(x_test)

# %%
print("Accuracy : ", accuracy_score(y_test, y_pred_svc))
# Out:
# Accuracy :  0.35043668122270744

# %% [markdown]
# ### Prediction

# %%
Xnew = [[1,24,15000,0,2,5]]

ynew = model_dt.predict(Xnew)

print(ynew)
# Out:
# ['Average']

# %%
y_test
# Out:
# array(['Average', 'High', 'High', 'Average', 'Average', 'Low', 'Average',
#        'Average', 'Average', 'Low', 'Low', 'High', 'Average', 'Low',
#        'High', 'Low', 'Average', 'Low', 'Low', 'High', 'Low', 'Low',
#        'Average', 'High', 'Average', 'Low', 'Low', 'Average', 'Average',
#        'Average', 'Average', 'High', 'High', 'Low', 'Low', 'High',
#        'Average', 'Low', 'High', 'Low', 'Average', 'Average', 'High',
#        'High', 'Average', 'Low', 'Average', 'Average', 'Low', 'Average',
#        'Average', 'High', 'Low', 'Average', 'High', 'Low', 'Average',
#        'High', 'Average', 'High', 'Low', 'Low', 'Average', 'High', 'Low',
#        'High', 'High', 'High', 'Average', 'High', 'Average', 'Low', 'Low',
#        'Low', 'High', 'Average', 'Average', 'Low', 'Average', 'Low',
#        'High', 'Low', 'High', 'Average', 'Average', 'Average', 'Average',
#        'Average', 'Average', 'High', 'High', 'High', 'Average', 'Average',
#        'Average', 'Average', 'Average', 'High', 'High', 'Average', 'Low',
#        'Average', 'Average', 'Average', 'Low', 'Average', 'High', 'High',
#        'Average', 'Low', 'Average', 'Low', 'High', 'Low', 'Average',
#        'High', 'High', 'High', 'Low', 'Low', 'Low', 'Average', 'Low',
#        'High', 'Average', 'High', 'High', 'Average', 'Average', 'High',
#        'Low', 'Low', 'High', 'High', 'High', 'High', 'Average', 'High',
#        'Average', 'Low', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'Average', 'Average', 'Average', 'Average', 'Low', 'High',
#        'Low', 'Average', 'Low', 'Low', 'High', 'Average', 'Average',
#        'Average', 'High', 'High', 'High', 'Low', 'High', 'High', 'High',
#        'Low', 'Average', 'High', 'High', 'High', 'Average', 'Low',
#        'Average', 'High', 'High', 'Low', 'High', 'Average', 'High',
#        'Average', 'Low', 'High', 'Average', 'High', 'Average', 'Low',
#        'Low', 'Average', 'High', 'High', 'Average', 'Low', 'Low', 'Low',
#        'High', 'Average', 'Low', 'Average', 'Low', 'High', 'Average',
#        'Low', 'Average', 'Low', 'Low', 'Low', 'Average', 'Low', 'High',
#        'Low', 'High', 'Low', 'High', 'Low', 'High', 'Low', 'High', 'Low',
#        'High', 'Low', 'Average', 'High', 'Low', 'High', 'High', 'Average',
#        'Low', 'Low', 'Average', 'Average', 'High', 'High', 'Low',
#        'Average', 'Average', 'Low', 'Average', 'Average', 'Low', 'Low',
#        'Average', 'High', 'Average', 'Low', 'Low', 'Low', 'High', 'High',
#        'Average', 'High', 'Average', 'High', 'Low', 'Low', 'Average',
#        'Low', 'Low', 'High', 'Low', 'Average', 'Low', 'High', 'High',
#        'Low', 'Average', 'High', 'Low', 'Low', 'Average', 'Average',
#        'High', 'High', 'Low', 'Average', 'High', 'Average', 'Average',
#        'Low', 'Average', 'High', 'High', 'Low', 'Average', 'High', 'High',
#        'Low', 'High', 'Low', 'Average', 'High', 'High', 'Average', 'High',
#        'Average', 'High', 'High', 'Average', 'Average', 'High', 'Low',
#        'Average', 'High', 'Low', 'Low', 'High', 'High', 'Low', 'High',
#        'Low', 'High', 'Average', 'Low', 'Low', 'Low', 'High', 'Average',
#        'High', 'Average', 'Low', 'Low', 'High', 'Average', 'Low', 'High',
#        'Low', 'Low', 'Low', 'Average', 'Low', 'Low', 'High', 'Average',
#        'High', 'High', 'Average', 'Average', 'Low', 'Low', 'Low', 'High',
#        'High', 'High', 'Average', 'High', 'Low', 'High', 'Low', 'Low',
#        'High', 'Average', 'Average', 'Average', 'Average', 'Average',
#        'High', 'High', 'Average', 'Low', 'Low', 'High', 'High', 'Low',
#        'High', 'Low', 'Low', 'Average', 'High', 'High', 'High', 'High',
#        'Average', 'Average', 'Average', 'Low', 'Average', 'Low',
#        'Average', 'Low', 'High', 'Low', 'Low', 'Average', 'Low', 'Low',
#        'Low', 'High', 'High', 'Average', 'Low', 'High', 'Low', 'Average',
#        'High', 'High', 'High', 'Average', 'Average', 'Average', 'High',
#        'High', 'High', 'Low', 'Low', 'High', 'High', 'High', 'Low',
#        'High', 'Average', 'Average', 'Low', 'Average', 'Average',
#        'Average', 'Low', 'Average', 'High', 'Average', 'High', 'Low',
#        'High', 'Average', 'Average', 'Average', 'Low', 'Low', 'Average',
#        'Low', 'Low', 'Average', 'High', 'Low', 'High', 'Average', 'High',
#        'Average', 'High', 'Low', 'Average', 'Low', 'Average', 'Low',
#        'Average', 'High', 'High', 'High', 'High', 'High', 'Average',
#        'Low', 'Low', 'Average', 'Low', 'Average', 'High', 'Average',
#        'High', 'Low', 'Low', 'High', 'Average', 'High', 'Average', 'Low',
#        'High', 'Average', 'Average', 'High', 'High', 'Average', 'High',
#        'Low', 'High', 'Average', 'High', 'High', 'High', 'Low', 'Low',
#        'Average', 'High', 'Average', 'Average', 'High', 'Average', 'Low',
#        'High', 'Average', 'Average', 'High', 'High', 'Average', 'Average',
#        'Low', 'Average', 'Average', 'Average', 'Low', 'High', 'Average',
#        'High', 'Low', 'High', 'High', 'Low', 'High', 'Average', 'Average',
#        'High', 'High', 'Low', 'Low', 'Average', 'Average', 'High', 'Low',
#        'Low', 'Low', 'High', 'Low', 'High', 'Average', 'Low', 'High',
#        'Low', 'Average', 'Average', 'Low', 'High', 'High', 'Average',
#        'Average', 'Average', 'Low', 'High', 'Average', 'High', 'Average',
#        'Average', 'High', 'High', 'High', 'Low', 'Low', 'High', 'Low',
#        'High', 'Low', 'Average', 'High', 'High', 'Low', 'Low', 'Low',
#        'Low', 'Low', 'High', 'Average', 'Average', 'Low', 'Average',
#        'Low', 'Average', 'Average', 'Average', 'Low', 'Average', 'Low',
#        'Low', 'Average', 'Low', 'High', 'High', 'Average', 'Average',
#        'Low', 'High', 'High', 'Low', 'High', 'Average', 'Low', 'Low',
#        'High', 'High', 'Low', 'High', 'High', 'High', 'High', 'Low',
#        'Low', 'Low', 'High', 'Low', 'Low', 'Average', 'Average', 'Low',
#        'Low', 'High', 'Low', 'Low', 'High', 'Low', 'High', 'Average',
#        'Low', 'Low', 'Low', 'Low', 'High', 'Low', 'Average', 'Average',
#        'High', 'Low', 'Low', 'Average', 'Low', 'Low', 'Average', 'High',
#        'Low', 'High', 'High', 'Low', 'Low', 'Low', 'Low', 'Low', 'High',
#        'Low', 'Average', 'Low', 'Low', 'Average', 'Average', 'Average',
#        'Average', 'High', 'High', 'Low', 'Average', 'Average', 'Average',
#        'Average', 'Average', 'Average', 'Low', 'Average', 'High', 'High',
#        'Low', 'High', 'Average', 'High', 'High', 'Low', 'Average', 'Low',
#        'Average', 'Average', 'Low', 'Average', 'Low', 'High', 'Low',
#        'Low', 'High', 'Low', 'Average', 'High', 'Average', 'Average',
#        'Average', 'High', 'Average', 'Low', 'Average', 'Low', 'Average',
#        'Average', 'Low', 'Average', 'High', 'High', 'High', 'Low',
#        'Average', 'Average', 'Average', 'Average', 'Low', 'Low',
#        'Average', 'Average', 'Average', 'High', 'Average', 'High',
#        'Average', 'Average', 'Average', 'High', 'Low', 'High', 'Low',
#        'Low', 'Average', 'Average', 'High', 'Low', 'High', 'Low',
#        'Average', 'Average', 'Average', 'High', 'Low', 'Low', 'Low',
#        'Average', 'Low', 'Low', 'Average', 'Average', 'High', 'Low',
#        'Low', 'Low', 'High', 'Low', 'High', 'Average', 'Low', 'High',
#        'Low', 'Average', 'Average', 'Low', 'High', 'Average', 'Average',
#        'Average', 'High', 'Low', 'Average', 'Low', 'Low', 'High',
#        'Average', 'Average', 'High', 'Low', 'Low', 'Low', 'Average',
#        'Low', 'Low', 'Average', 'High', 'Low', 'High', 'Average', 'Low',
#        'High', 'Low', 'Average', 'High', 'High', 'Low', 'Low', 'High',
#        'High', 'High', 'High', 'High', 'Low', 'Average', 'Low', 'Low',
#        'High', 'Low', 'Average', 'Low', 'Low', 'Average', 'Low', 'Low',
#        'Average', 'High', 'Low', 'Average', 'High', 'Average', 'Average',
#        'Average', 'Low', 'Low', 'Average', 'Average', 'Average', 'High',
#        'Low', 'Average', 'Average', 'Average', 'Low', 'High', 'Average',
#        'Average', 'High', 'Low', 'Average', 'High', 'Low', 'Low', 'High',
#        'Average', 'Average', 'Low', 'High', 'Average', 'Average', 'Low',
#        'Average', 'Low', 'Low', 'Average', 'High', 'Low', 'Low',
#        'Average', 'Low', 'Low', 'Average', 'Average', 'Average', 'High',
#        'High', 'Low', 'Average', 'Low', 'Low', 'Low', 'Low', 'High',
#        'High', 'High', 'Low', 'Low', 'Average', 'High', 'Average', 'High',
#        'High', 'Average', 'Average', 'Low', 'Average', 'Average', 'Low',
#        'Average', 'Low', 'Average', 'Low', 'Low', 'High', 'Low', 'Low',
#        'Average', 'Low', 'Low', 'Average', 'High', 'High', 'Average',
#        'Average', 'High', 'Average', 'High', 'Average', 'Average',
#        'Average', 'High', 'Average', 'Low', 'High', 'Low', 'Low', 'Low',
#        'Average', 'Average', 'High', 'High', 'Low', 'High', 'Average',
#        'High', 'Average', 'High', 'Low', 'Low', 'Low', 'Average', 'High',
#        'Average', 'Average', 'Low', 'Average', 'High', 'Low'],
#       dtype=object)

# %%
y_pred_dt
# Out:
# array(['High', 'Low', 'Low', 'Average', 'Average', 'Low', 'High',
#        'Average', 'Average', 'Low', 'Low', 'High', 'Average', 'Average',
#        'High', 'Low', 'Average', 'Low', 'Low', 'High', 'Low', 'Low',
#        'Average', 'Average', 'Average', 'Low', 'Low', 'High', 'Average',
#        'High', 'Average', 'Average', 'High', 'High', 'Low', 'Low',
#        'Average', 'Low', 'High', 'Low', 'Average', 'High', 'High', 'Low',
#        'High', 'Low', 'Average', 'Average', 'Low', 'Average', 'High',
#        'Average', 'Low', 'Average', 'High', 'Low', 'High', 'Average',
#        'High', 'High', 'Low', 'Low', 'Average', 'High', 'Low', 'Low',
#        'High', 'Average', 'Average', 'High', 'Average', 'Low', 'Average',
#        'Low', 'Average', 'High', 'Average', 'Low', 'Average', 'Low',
#        'High', 'Low', 'Low', 'Average', 'Average', 'Average', 'Low',
#        'Low', 'High', 'High', 'Low', 'High', 'Average', 'Average',
#        'Average', 'High', 'Average', 'High', 'High', 'Average', 'Low',
#        'High', 'Average', 'Average', 'Low', 'Low', 'Low', 'High',
#        'Average', 'Low', 'Average', 'Low', 'High', 'Low', 'Average',
#        'High', 'High', 'Average', 'Low', 'Low', 'Low', 'Average', 'Low',
#        'Low', 'Average', 'Low', 'High', 'Average', 'High', 'High', 'High',
#        'Low', 'High', 'High', 'High', 'High', 'Average', 'High',
#        'Average', 'Low', 'Low', 'High', 'High', 'Average', 'Low', 'High',
#        'High', 'Average', 'Average', 'Average', 'Low', 'Low', 'Low',
#        'Average', 'High', 'Average', 'Low', 'High', 'Average', 'Average',
#        'Average', 'Low', 'High', 'Low', 'Low', 'Low', 'High', 'Low',
#        'Low', 'Average', 'Low', 'Low', 'High', 'High', 'Low', 'Average',
#        'High', 'Average', 'Low', 'Low', 'High', 'Average', 'Average',
#        'Low', 'Average', 'Average', 'Average', 'Average', 'Low', 'High',
#        'High', 'Average', 'High', 'Average', 'Low', 'Low', 'Low', 'Low',
#        'Average', 'Low', 'Average', 'Low', 'High', 'Average', 'Low',
#        'Average', 'Low', 'Low', 'Low', 'Average', 'Low', 'High', 'Low',
#        'Average', 'Low', 'High', 'Low', 'High', 'Low', 'High', 'Low',
#        'High', 'Low', 'Average', 'Low', 'High', 'Low', 'Average', 'High',
#        'Low', 'Low', 'Average', 'High', 'Low', 'Low', 'Low', 'Average',
#        'High', 'Low', 'Average', 'Average', 'High', 'High', 'Average',
#        'High', 'High', 'Low', 'Low', 'High', 'Low', 'High', 'Average',
#        'High', 'Average', 'Average', 'Low', 'High', 'Low', 'Average',
#        'Low', 'High', 'Average', 'Average', 'Low', 'Average', 'High',
#        'Low', 'High', 'High', 'Low', 'Low', 'High', 'Average', 'Average',
#        'High', 'Low', 'Low', 'High', 'Average', 'High', 'Low', 'Average',
#        'Low', 'High', 'Average', 'Average', 'High', 'Average', 'Low',
#        'High', 'Low', 'High', 'Low', 'High', 'High', 'High', 'Average',
#        'High', 'Low', 'Average', 'Average', 'High', 'Low', 'Low', 'High',
#        'Low', 'Low', 'High', 'Average', 'High', 'Average', 'Low', 'Low',
#        'Average', 'Low', 'Low', 'Low', 'Low', 'Average', 'Average',
#        'Average', 'Average', 'Low', 'High', 'Average', 'Low', 'Low',
#        'Low', 'High', 'Low', 'Average', 'Low', 'Low', 'High', 'Low',
#        'High', 'Low', 'High', 'High', 'Low', 'Low', 'Low', 'Average',
#        'Average', 'Average', 'Average', 'High', 'High', 'Average', 'Low',
#        'Average', 'Low', 'Average', 'Average', 'Average', 'Average',
#        'Average', 'Low', 'Average', 'Average', 'Average', 'Low', 'Low',
#        'Average', 'Average', 'Average', 'Low', 'Low', 'Average', 'High',
#        'Low', 'Average', 'Average', 'Average', 'Average', 'Average',
#        'Low', 'High', 'Low', 'Average', 'Low', 'Low', 'Low', 'Low',
#        'High', 'Low', 'Low', 'Low', 'High', 'High', 'Average', 'Low',
#        'Low', 'High', 'Average', 'High', 'High', 'Low', 'Average',
#        'Average', 'Average', 'High', 'High', 'Low', 'Low', 'High', 'High',
#        'High', 'Low', 'Low', 'High', 'Average', 'Average', 'Low',
#        'Average', 'High', 'Average', 'Low', 'Average', 'High', 'High',
#        'High', 'Low', 'High', 'Low', 'High', 'Average', 'Low', 'Low',
#        'Average', 'Low', 'Low', 'Average', 'High', 'Low', 'Low', 'Low',
#        'High', 'Average', 'High', 'Low', 'Average', 'Low', 'Average',
#        'Low', 'High', 'Low', 'High', 'High', 'Average', 'High', 'Average',
#        'Low', 'Low', 'Average', 'Low', 'High', 'Low', 'Average', 'High',
#        'Low', 'High', 'High', 'High', 'High', 'Average', 'Low', 'High',
#        'Low', 'Average', 'Low', 'Average', 'Average', 'Average', 'Low',
#        'Low', 'Average', 'High', 'Average', 'High', 'Low', 'Low',
#        'Average', 'Low', 'High', 'High', 'High', 'Average', 'Low', 'Low',
#        'Average', 'Average', 'High', 'Low', 'Average', 'Average', 'Low',
#        'Average', 'High', 'Average', 'Low', 'High', 'Low', 'High', 'Low',
#        'High', 'High', 'Low', 'High', 'Average', 'High', 'High', 'High',
#        'Low', 'Low', 'Average', 'Average', 'High', 'Low', 'Low', 'Low',
#        'Average', 'Low', 'High', 'High', 'Low', 'High', 'Low', 'Average',
#        'Average', 'Low', 'Average', 'High', 'Average', 'Average', 'High',
#        'High', 'High', 'Average', 'High', 'Average', 'Average', 'Average',
#        'High', 'Low', 'Low', 'Low', 'High', 'Low', 'Average', 'High',
#        'Average', 'Low', 'Average', 'Average', 'Low', 'Low', 'Low', 'Low',
#        'Low', 'High', 'Average', 'Average', 'High', 'Low', 'Average',
#        'Average', 'Average', 'Average', 'Average', 'Low', 'High', 'Low',
#        'Low', 'Low', 'High', 'Average', 'High', 'Low', 'High', 'High',
#        'Low', 'Average', 'Average', 'Low', 'Low', 'High', 'Average',
#        'Low', 'High', 'High', 'Average', 'High', 'Low', 'Average', 'Low',
#        'High', 'Low', 'Low', 'Average', 'Average', 'Low', 'Low', 'High',
#        'Low', 'Low', 'High', 'Low', 'High', 'Average', 'Low', 'Low',
#        'Low', 'Low', 'High', 'High', 'High', 'High', 'Average', 'Low',
#        'Low', 'Average', 'Low', 'High', 'High', 'Low', 'Low', 'Average',
#        'High', 'Low', 'Low', 'Low', 'Low', 'Low', 'High', 'High',
#        'Average', 'Low', 'Low', 'Average', 'Average', 'Average',
#        'Average', 'High', 'High', 'Low', 'High', 'Average', 'Average',
#        'High', 'Average', 'Average', 'Low', 'High', 'High', 'Average',
#        'Low', 'Average', 'Average', 'High', 'Low', 'Low', 'Average',
#        'Low', 'Average', 'Average', 'Low', 'High', 'Low', 'Average',
#        'Low', 'Average', 'Low', 'Low', 'High', 'High', 'High', 'Average',
#        'Average', 'Low', 'Average', 'Low', 'Average', 'Low', 'High',
#        'Average', 'Low', 'Average', 'Low', 'High', 'High', 'Low',
#        'Average', 'Average', 'Average', 'High', 'Low', 'Low', 'Average',
#        'Average', 'Average', 'High', 'Average', 'High', 'High', 'Low',
#        'Average', 'High', 'Low', 'Low', 'Low', 'Low', 'High', 'High',
#        'High', 'Low', 'Low', 'Low', 'High', 'High', 'Average', 'Average',
#        'Low', 'Low', 'Low', 'High', 'Low', 'Low', 'Average', 'High',
#        'High', 'Low', 'Low', 'Low', 'High', 'Low', 'Low', 'High', 'Low',
#        'High', 'Low', 'High', 'Average', 'Low', 'Average', 'Average',
#        'Average', 'Average', 'Low', 'Low', 'Average', 'Low', 'Low', 'Low',
#        'Average', 'Average', 'Average', 'Low', 'Low', 'Low', 'Average',
#        'Low', 'Low', 'Average', 'High', 'Low', 'High', 'Average', 'Low',
#        'High', 'Low', 'High', 'Low', 'High', 'Low', 'Low', 'High', 'High',
#        'Average', 'High', 'High', 'Low', 'Average', 'Low', 'Low',
#        'Average', 'Low', 'Average', 'Low', 'Low', 'High', 'Low', 'Low',
#        'High', 'Average', 'Low', 'High', 'Average', 'High', 'High',
#        'Average', 'Low', 'Low', 'High', 'Average', 'Average', 'Average',
#        'Low', 'Average', 'Average', 'Average', 'Low', 'Average',
#        'Average', 'Average', 'Low', 'Low', 'Average', 'Average', 'Low',
#        'Low', 'Low', 'High', 'Average', 'Low', 'Average', 'Average',
#        'Low', 'Low', 'Average', 'Low', 'High', 'Average', 'Average',
#        'Low', 'Low', 'Average', 'Low', 'Low', 'High', 'Average',
#        'Average', 'High', 'Average', 'Low', 'Average', 'Low', 'Low',
#        'Low', 'Low', 'High', 'High', 'High', 'Low', 'Low', 'Average',
#        'Low', 'Average', 'Average', 'High', 'Average', 'Average', 'Low',
#        'Average', 'Average', 'Low', 'Average', 'Low', 'Average', 'Low',
#        'Low', 'High', 'Low', 'Low', 'Average', 'Low', 'Low', 'High',
#        'High', 'Average', 'High', 'Average', 'High', 'Average', 'High',
#        'Average', 'Average', 'Average', 'High', 'Low', 'Low', 'Average',
#        'Low', 'Low', 'Low', 'Average', 'Average', 'High', 'High', 'Low',
#        'Low', 'Average', 'High', 'Average', 'High', 'High', 'Low', 'Low',
#        'Average', 'High', 'Average', 'Average', 'Low', 'Average', 'High',
#        'Low'], dtype=object)

# %% [markdown]
# ### DATA ANALYTICS

# %%
l1 = list(y_test)
l2 = list(y_pred_dt)

# %%
pred = {}
for i, score in enumerate(l1):
  pred[i] = score

# %%
pred1 = {}
for i, score in enumerate(l2):
  pred1[i] = score

# %%
dct={'y_test':pred , 'y_pred_dt': pred1}

# %%
data = pd.DataFrame(dct)

# %%
print(data)
# Out:
#       y_test y_pred_dt
# 0    Average      High
# 1       High       Low
# 2       High       Low
# 3    Average   Average
# 4    Average   Average
# ..       ...       ...
# 911  Average   Average
# 912      Low       Low
# 913  Average   Average
# 914     High      High
# 915      Low       Low
#
# [916 rows x 2 columns]

# %%
data.to_excel("output.xlsx")
